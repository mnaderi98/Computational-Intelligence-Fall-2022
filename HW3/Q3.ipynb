# %%
# !pip install simpful
import simpful as sf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: simpful in /usr/local/lib/python3.8/dist-packages (2.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from simpful) (2.25.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from simpful) (1.7.3)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from simpful) (1.21.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->simpful) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->simpful) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->simpful) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->simpful) (4.0.0)

# %%
FS = sf.FuzzySystem()

#برحسب سیلسیوس
temp = sf.AutoTriangle(4, terms=['very_cold', 'cold', 'hot', 'very_hot'], universe_of_discourse=[-5, 100])

FS.add_linguistic_variable("1_day_ago_tmp", temp)
FS.add_linguistic_variable("2_days_ago_tmp", temp)
FS.add_linguistic_variable("3_days_ago_tmp", temp)
FS.add_linguistic_variable("today_tmp", temp)

#برحسب درصد
hmdt = sf.AutoTriangle(5, terms=['very_low', 'low', 'normal', 'high', 'very_high'], universe_of_discourse=[0, 100])
FS.add_linguistic_variable("humidity", hmdt)
#برحسب میلیمتر
rain_fall = sf.AutoTriangle(5, terms=['very_low', 'low', 'normal', 'much', 'very_much'], universe_of_discourse=[0, 2500])
FS.add_linguistic_variable("rain_fall", rain_fall)
#برحسب متر
height = sf.AutoTriangle(5, terms=['very_low', 'low', 'normal', 'high', 'very_high'], universe_of_discourse=[0, 5500])
FS.add_linguistic_variable("height", height)
# Out:
#   ____  __  _  _  ____  ____  _  _  __
#  / ___)(  )( \/ )(  _ \(  __)/ )( \(  ) v2.9.0
#  \___ \ )( / \/ \ ) __/ ) _) ) \/ (/ (_/\
#  (____/(__)\_)(_/(__)  (__)  \____/\____/
#
#  Created by Marco S. Nobile (m.s.nobile@tue.nl)
#  and Simone Spolaor (simone.spolaor@unimib.it)

# %%
RULE1 = "IF (1_day_ago_tmp IS cold) AND (rain_fall IS much) THEN (today_tmp IS cold)"
RULE2 = "IF (1_day_ago_tmp IS very_cold) AND (rain_fall IS very_much) THEN (today_tmp IS very_cold)"
RULE3 = "IF (1_day_ago_tmp IS hot) OR (3_days_ago_tmp IS hot) THEN (today_tmp IS hot)"
RULE4 = "IF (1_day_ago_tmp IS very_hot) AND (2_days_ago_tmp IS very_hot) THEN (today_tmp IS very_hot)"
RULE5 = "IF (1_day_ago_tmp IS cold) OR (rain_fall IS very_low) THEN (today_tmp IS hot)"
RULE6 = "IF (1_day_ago_tmp IS very_cold) OR (3_days_ago_tmp IS very_cold) THEN (today_tmp IS very_cold)"
RULE7 = "IF (3_days_ago_tmp IS cold) OR (2_days_ago_tmp IS cold) THEN (today_tmp IS cold)"
RULE8 = "IF (3_days_ago_tmp IS very_hot) AND (2_days_ago_tmp IS hot) AND (1_day_ago_tmp IS cold) THEN (today_tmp IS very_cold)"
RULE9 = "IF (humidity IS high) AND (rain_fall IS normal) THEN (today_tmp IS hot)"
RULE10 = "IF (height IS very_low) AND (rain_fall IS very_much) THEN (today_tmp IS very_cold)"
RULE11 = "IF (height IS normal)  OR (rain_fall IS very_low) THEN (today_tmp IS hot)"
RULE12 = "IF (height IS high) AND (rain_fall IS normal) THEN (today_tmp IS hot)"

FS.add_rules([RULE1, RULE2, RULE3, RULE4, RULE5, RULE6, RULE7, RULE8, RULE9, RULE10, RULE11, RULE12], verbose=True)
# Out:
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (1_day_ago_tmp IS cold) AND (rain_fall IS much)
#   -- Found (1_day_ago_tmp IS cold) *AND* (rain_fall IS much)
#  * Simple clause with parentheses matched
#  * Rule: c.(1_day_ago_tmp IS cold)
#  * Simple clause with parentheses matched
#  * Rule: c.(rain_fall IS much)
#  * Added rule IF f.(c.(1_day_ago_tmp IS cold) AND c.(rain_fall IS much)) THEN ('today_tmp', 'cold')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (1_day_ago_tmp IS very_cold) AND (rain_fall IS very_much)
#   -- Found (1_day_ago_tmp IS very_cold) *AND* (rain_fall IS very_much)
#  * Simple clause with parentheses matched
#  * Rule: c.(1_day_ago_tmp IS very_cold)
#  * Simple clause with parentheses matched
#  * Rule: c.(rain_fall IS very_much)
#  * Added rule IF f.(c.(1_day_ago_tmp IS very_cold) AND c.(rain_fall IS very_much)) THEN ('today_tmp', 'very_cold')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (1_day_ago_tmp IS hot) OR (3_days_ago_tmp IS hot)
#   -- Found (1_day_ago_tmp IS hot) *OR* (3_days_ago_tmp IS hot)
#  * Simple clause with parentheses matched
#  * Rule: c.(1_day_ago_tmp IS hot)
#  * Simple clause with parentheses matched
#  * Rule: c.(3_days_ago_tmp IS hot)
#  * Added rule IF f.(c.(1_day_ago_tmp IS hot) OR c.(3_days_ago_tmp IS hot)) THEN ('today_tmp', 'hot')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (1_day_ago_tmp IS very_hot) AND (2_days_ago_tmp IS very_hot)
#   -- Found (1_day_ago_tmp IS very_hot) *AND* (2_days_ago_tmp IS very_hot)
#  * Simple clause with parentheses matched
#  * Rule: c.(1_day_ago_tmp IS very_hot)
#  * Simple clause with parentheses matched
#  * Rule: c.(2_days_ago_tmp IS very_hot)
#  * Added rule IF f.(c.(1_day_ago_tmp IS very_hot) AND c.(2_days_ago_tmp IS very_hot)) THEN ('today_tmp', 'very_hot')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (1_day_ago_tmp IS cold) OR (rain_fall IS very_low)
#   -- Found (1_day_ago_tmp IS cold) *OR* (rain_fall IS very_low)
#  * Simple clause with parentheses matched
#  * Rule: c.(1_day_ago_tmp IS cold)
#  * Simple clause with parentheses matched
#  * Rule: c.(rain_fall IS very_low)
#  * Added rule IF f.(c.(1_day_ago_tmp IS cold) OR c.(rain_fall IS very_low)) THEN ('today_tmp', 'hot')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (1_day_ago_tmp IS very_cold) OR (3_days_ago_tmp IS very_cold)
#   -- Found (1_day_ago_tmp IS very_cold) *OR* (3_days_ago_tmp IS very_cold)
#  * Simple clause with parentheses matched
#  * Rule: c.(1_day_ago_tmp IS very_cold)
#  * Simple clause with parentheses matched
#  * Rule: c.(3_days_ago_tmp IS very_cold)
#  * Added rule IF f.(c.(1_day_ago_tmp IS very_cold) OR c.(3_days_ago_tmp IS very_cold)) THEN ('today_tmp', 'very_cold')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (3_days_ago_tmp IS cold) OR (2_days_ago_tmp IS cold)
#   -- Found (3_days_ago_tmp IS cold) *OR* (2_days_ago_tmp IS cold)
#  * Simple clause with parentheses matched
#  * Rule: c.(3_days_ago_tmp IS cold)
#  * Simple clause with parentheses matched
#  * Rule: c.(2_days_ago_tmp IS cold)
#  * Added rule IF f.(c.(3_days_ago_tmp IS cold) OR c.(2_days_ago_tmp IS cold)) THEN ('today_tmp', 'cold')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (3_days_ago_tmp IS very_hot) AND (2_days_ago_tmp IS hot) AND (1_day_ago_tmp IS cold)
#   -- Found (3_days_ago_tmp IS very_hot) *AND* (2_days_ago_tmp IS hot) AND (1_day_ago_tmp IS cold)
#  * Simple clause with parentheses matched
#  * Rule: c.(3_days_ago_tmp IS very_hot)
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (2_days_ago_tmp IS hot) AND (1_day_ago_tmp IS cold)
#   -- Found (2_days_ago_tmp IS hot) *AND* (1_day_ago_tmp IS cold)
#  * Simple clause with parentheses matched
#  * Rule: c.(2_days_ago_tmp IS hot)
#  * Simple clause with parentheses matched
#  * Rule: c.(1_day_ago_tmp IS cold)
#  * Added rule IF f.(c.(3_days_ago_tmp IS very_hot) AND f.(c.(2_days_ago_tmp IS hot) AND c.(1_day_ago_tmp IS cold))) THEN ('today_tmp', 'very_cold')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (humidity IS high) AND (rain_fall IS normal)
#   -- Found (humidity IS high) *AND* (rain_fall IS normal)
#  * Simple clause with parentheses matched
#  * Rule: c.(humidity IS high)
#  * Simple clause with parentheses matched
#  * Rule: c.(rain_fall IS normal)
#  * Added rule IF f.(c.(humidity IS high) AND c.(rain_fall IS normal)) THEN ('today_tmp', 'hot')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (height IS very_low) AND (rain_fall IS very_much)
#   -- Found (height IS very_low) *AND* (rain_fall IS very_much)
#  * Simple clause with parentheses matched
#  * Rule: c.(height IS very_low)
#  * Simple clause with parentheses matched
#  * Rule: c.(rain_fall IS very_much)
#  * Added rule IF f.(c.(height IS very_low) AND c.(rain_fall IS very_much)) THEN ('today_tmp', 'very_cold')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (height IS normal)  OR (rain_fall IS very_low)
#   -- Found (height IS normal) *OR* (rain_fall IS very_low)
#  * Simple clause with parentheses matched
#  * Rule: c.(height IS normal)
#  * Simple clause with parentheses matched
#  * Rule: c.(rain_fall IS very_low)
#  * Added rule IF f.(c.(height IS normal) OR c.(rain_fall IS very_low)) THEN ('today_tmp', 'hot')
#
#  * Regular expression is not matching with single atomic clause
#  * Looking for an operator in (height IS high) AND (rain_fall IS normal)
#   -- Found (height IS high) *AND* (rain_fall IS normal)
#  * Simple clause with parentheses matched
#  * Rule: c.(height IS high)
#  * Simple clause with parentheses matched
#  * Rule: c.(rain_fall IS normal)
#  * Added rule IF f.(c.(height IS high) AND c.(rain_fall IS normal)) THEN ('today_tmp', 'hot')
#
#  * 12 rules successfully added

# %% [markdown]
# # **ptrdiction**

# %%
FS.set_variable("1_day_ago_tmp", -1)
FS.set_variable("2_days_ago_tmp", 6)
FS.set_variable("3_days_ago_tmp", 14)
FS.set_variable("humidity", 35)
FS.set_variable("rain_fall", 750)
FS.set_variable("height", 20)

# %%
result = FS.inference()
print(result)
# Out:
# {'today_tmp': 28.828796721262986}
