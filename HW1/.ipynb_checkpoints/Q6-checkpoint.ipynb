# %% [markdown]
# # Q6
# calling libraries

# %%
from keras import Model

from keras.layers import *

from keras.optimizers import *

from keras.models import Sequential

import keras

from keras.datasets import mnist

import numpy as np

import matplotlib.pyplot as plt

# %% [markdown]
# ### Data Set

# %%
class_number = 10
image_number = 784

(x_train, y_train), (x_test, y_test) = mnist.load_data()

train_dims = x_train.shape[0]
test_dims = x_test.shape[0]

x_train = x_train.reshape((train_dims, image_number))
x_test = x_test.reshape((test_dims, image_number))

y_train = keras.utils.to_categorical(y_train, class_number)
y_test = keras.utils.to_categorical(y_test, class_number)

# %% [markdown]
# ### creating a Multiple Layer Perceptron

# %%
visible = Input(shape = x_train[0].shape)
layer = Dense(units = 392, activation = 'relu')(visible)
layer = Dense(units = 196, activation = 'relu')(layer)
layer = Dense(units = 98, activation = 'relu')(layer)
layer = Dense(units = class_number, activation = 'softmax')(layer)
model = Model(inputs = visible, outputs = layer)

model.summary()

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=250,
                    epochs=25,
                    validation_data=(x_test, y_test))

print(history.history.keys())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 784)]             0
#
#  dense_3 (Dense)             (None, 392)               307720
#
#  dense_4 (Dense)             (None, 196)               77028
#
#  dense_5 (Dense)             (None, 98)                19306
#
#  dense_6 (Dense)             (None, 10)                990
#
# =================================================================
# Total params: 405,044
# Trainable params: 405,044
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 240/240 [==============================] - 4s 12ms/step - loss: 2.9992 - accuracy: 0.8692 - val_loss: 0.5563 - val_accuracy: 0.9255
# Epoch 2/25
# 240/240 [==============================] - 3s 13ms/step - loss: 0.3444 - accuracy: 0.9432 - val_loss: 0.3669 - val_accuracy: 0.9438
# Epoch 3/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.1883 - accuracy: 0.9610 - val_loss: 0.3356 - val_accuracy: 0.9436
# Epoch 4/25
# 240/240 [==============================] - 3s 13ms/step - loss: 0.1151 - accuracy: 0.9730 - val_loss: 0.2759 - val_accuracy: 0.9515
# Epoch 5/25
# 240/240 [==============================] - 4s 15ms/step - loss: 0.0868 - accuracy: 0.9779 - val_loss: 0.2928 - val_accuracy: 0.9556
# Epoch 6/25
# 240/240 [==============================] - 4s 15ms/step - loss: 0.0641 - accuracy: 0.9825 - val_loss: 0.2563 - val_accuracy: 0.9575
# Epoch 7/25
# 240/240 [==============================] - 4s 15ms/step - loss: 0.0580 - accuracy: 0.9841 - val_loss: 0.2649 - val_accuracy: 0.9596
# Epoch 8/25
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0526 - accuracy: 0.9858 - val_loss: 0.2833 - val_accuracy: 0.9583
# Epoch 9/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.